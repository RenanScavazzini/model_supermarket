# %% [markdown]
# # 04 - Dashboard Interativo
#
# Este notebook demonstra a execução e integração do dashboard interativo do projeto `model_supermarket`, desenvolvido com Streamlit para visualização analítica de notas fiscais de supermercados.
#
# O dashboard utiliza os módulos da arquitetura do framework para carregar, processar e apresentar métricas, gráficos e análises em uma interface web interativa.
#
# As funcionalidades incluem:
#
# - visão geral de gastos
# - indicadores consolidados
# - análises temporais
# - análises de produtos
# - comparação entre supermercados
# - gráficos interativos
# - filtros dinâmicos
# - exploração analítica em tempo real
#
# O objetivo deste notebook é facilitar testes locais, validações da interface e demonstrações do painel analítico durante o desenvolvimento do projeto.

# %%
# !pip install -r requirements.txt

# %%
# IMPORTS
import subprocess
import webbrowser
import time
from pathlib import Path
import pandas as pd
import streamlit as st

from src.core.tictoc import tictoc
from src.core.config_loader import ConfigLoader
from src.core.paths import ROOT_DIR
from src.core.logger import setup_logger

# CONFIGURAÇÃO
logger = setup_logger(__name__)
tic_geral = time.time()

config = ConfigLoader(
    "config/settings.yaml"
)
dashboard_path = (
    ROOT_DIR
    / "src"
    / "dashboard"
    / "app.py"
)

port = 8509

# %% [markdown]
# ## 1. Inicialização do Dashboard

# %% [markdown]
# Nesta etapa será realizado:
#
# - carregamento das configurações do projeto
# - inicialização do ambiente Streamlit
# - carregamento dos dados analíticos
# - execução local do dashboard interativo
# - abertura automática da interface web para visualização das análises
#
# O dashboard utiliza os módulos analíticos do framework `model_supermarket` para geração dinâmica de métricas, gráficos e visualizações interativas.

# %%
tic = time.time()

# %%
# EXECUÇÃO DO DASHBOARD

process = subprocess.Popen(
    [
        "python",
        "-m",
        "streamlit",
        "run",
        str(dashboard_path),
        "--server.port",
        str(port)
    ]
)

time.sleep(8)

url = f"http://localhost:{port}"

print(
    f"Dashboard iniciado em:\n{url}"
)

# webbrowser.open(url)
# Out:
# Dashboard iniciado em:
# http://localhost:8509

# %%
toc = time.time()
print(f"\n\033[33mEtapa 1 | Tempo:\033[0;0m {tictoc(tic, toc)}")
# Out:
# Etapa 1 | Tempo: (00:00:08) [16/06/2026 00:14:08 - 16/06/2026 00:14:16]

# %% [markdown]
# ## 2. Carregamento dos Dados

# %% [markdown]
# Nesta etapa é realizado o carregamento da base de dados utilizada pelo dashboard.
#
# O objetivo é validar:
#
# - leitura do arquivo
# - estrutura do dataset
# - quantidade de registros
# - colunas disponíveis
# - integridade inicial dos dados

# %%
tic = time.time()

# %%
data_path = config.get(
    "paths.data"
)
df = pd.read_excel(data_path)
print(
    f"Linhas: {df.shape[0]}"
)
print(
    f"Colunas: {df.shape[1]}"
)
df.head()
# Out:
# Linhas: 3561
# Colunas: 25
#                                    chave_anonimizada           data_hora  \
# 0  fcb669525bd643f21cb51d896c86adfe0933f5cb868f32... 2022-06-28 20:44:50
# 1  fcb669525bd643f21cb51d896c86adfe0933f5cb868f32... 2022-06-28 20:44:50
# 2  fcb669525bd643f21cb51d896c86adfe0933f5cb868f32... 2022-06-28 20:44:50
# 3  fcb669525bd643f21cb51d896c86adfe0933f5cb868f32... 2022-06-28 20:44:50
# 4  fcb669525bd643f21cb51d896c86adfe0933f5cb868f32... 2022-06-28 20:44:50
#
#    mes_ano dia_semana feriado estacao_ano  temperatura_max  temperatura_min  \
# 0  2022-06      TERCA     NAO     INVERNO             21.3              9.8
# 1  2022-06      TERCA     NAO     INVERNO             21.3              9.8
# 2  2022-06      TERCA     NAO     INVERNO             21.3              9.8
# 3  2022-06      TERCA     NAO     INVERNO             21.3              9.8
# 4  2022-06      TERCA     NAO     INVERNO             21.3              9.8
#
#    temperatura_media  chuva_mm  ... qtd_total_nota  valor_total_nota  \
# 0               14.7       0.0  ...             82            679.79
# 1               14.7       0.0  ...             82            679.79
# 2               14.7       0.0  ...             82            679.79
# 3               14.7       0.0  ...             82            679.79
# 4               14.7       0.0  ...             82            679.79
#
#   valor_total_tributos  cod_produto     categoria_produto  \
# 0                76.32  10176020001                CEREAL
# 1                76.32  11421800001             MERCEARIA
# 2                76.32     18730001             MERCEARIA
# 3                76.32     65420001  BEBIDA NAO ALCOOLICA
# 4                76.32  10566170001                 MOLHO
#
#                 produto  unidade  quantidade  preco_unitario preco_total
# 0    CEREAL NESCAU 770G  UNIDADE         1.0           19.90       19.90
# 1  BEB VERY 1250G SALAD  UNIDADE         1.0            7.70        7.70
# 2  ARR T JOAO LF T1 5kg  UNIDADE         1.0           25.90       25.90
# 3  BEB NESQUIK 200ML MO  UNIDADE        10.0            2.89       28.90
# 4      EXT ELEF TP 140G  UNIDADE         2.0            2.59        5.18
#
# [5 rows x 25 columns]

# %%
toc = time.time()
print(f"\n\033[33mEtapa 2 | Tempo:\033[0;0m {tictoc(tic, toc)}")
# Out:
# Etapa 2 | Tempo: (00:00:02) [16/06/2026 00:14:16 - 16/06/2026 00:14:19]

# %% [markdown]
# ## 3. Tempo Decorrido

# %%
toc_geral = time.time()
print(f"\n\033[33mTempo decorrido no notebook:\033[0;0m {tictoc(tic_geral, toc_geral)}")
# Out:
# Tempo decorrido no notebook: (00:00:10) [16/06/2026 00:14:08 - 16/06/2026 00:14:19]
